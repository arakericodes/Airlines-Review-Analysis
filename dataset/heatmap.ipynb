# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("correlation_dataset.csv", delimiter=",")

# %%
df
# Out:
#       Unnamed: 0  Food & Beverages  Ground Service  Cabin Staff Service  \
# 0              0               4.0             4.0                  5.0
# 1              1               1.0             1.0                  2.0
# 2              2               1.0             1.0                  1.0
# 3              3               1.0             1.0                  1.0
# 4              4               1.0             1.0                  1.0
# ...          ...               ...             ...                  ...
# 8019        8019               1.0             1.0                  2.0
# 8020        8020               1.0             2.0                  2.0
# 8021        8021               1.0             1.0                  4.0
# 8022        8022               2.0             1.0                  4.0
# 8023        8023               3.0             1.0                  4.0
#
#       Seat Comfort  Value For Money  Overall_Rating
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Food & Beverages       0
# Ground Service         0
# Cabin Staff Service    0
# Seat Comfort           0
# Value For Money        0
# Overall_Rating         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Food & Beverages', 'Ground Service',
#        'Cabin Staff Service', 'Seat Comfort', 'Value For Money',
#        'Overall_Rating'],
#       dtype='object')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#       Food & Beverages  Ground Service  Cabin Staff Service  Seat Comfort  \
# 0                  4.0             4.0                  5.0           4.0
# 1                  1.0             1.0                  2.0           2.0
# 2                  1.0             1.0                  1.0           2.0
# 3                  1.0             1.0                  1.0           1.0
# 4                  1.0             1.0                  1.0           1.0
# ...                ...             ...                  ...           ...
# 8019               1.0             1.0                  2.0           2.0
# 8020               1.0             2.0                  2.0           2.0
# 8021               1.0             1.0                  4.0           3.0
# 8022               2.0             1.0                  4.0           2.0
# 8023               3.0             1.0                  4.0           3.0
#
#       Value For Money  Overall_Rating
# 0                 3.0               9
# ...

# %%
df_corr = df.corr()

# %%
sns.heatmap(df_corr, annot=True, cmap = "Blues")
# Out:
# <Axes: >
